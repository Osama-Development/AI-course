# %%
# ==============================================================================
#  ملف اختبار للتأكد من تثبيت جميع المكتبات بشكل صحيح في بيئة VS Code
#  قم بتشغيله بالضغط على أيقونة التشغيل (المثلث الأخضر) في الزاوية العلوية اليمنى.
# ==============================================================================

# متغير لتتبع حالة النجاح العامة
all_successful = True

# دالة لطباعة الترويسات بشكل منسق
def print_header(title):
    print("\n" + "-"*15 + f" {title} " + "-"*15)

# --- بدء عملية التحقق ---
print("="*50)
print("بدء عملية التحقق من تثبيت مكتبات الدورة...")
print("="*50)


# --- 1. مكتبات علم البيانات الأساسية ---
print_header("1. مكتبات علم البيانات الأساسية")
try:
    import numpy as np
    print(f"[✓] NumPy \t\t version: {np.__version__}")
except ImportError:
    print("[✗] NumPy \t\t - غير مثبتة!")
    all_successful = False

try:
    import pandas as pd
    print(f"[✓] Pandas \t\t version: {pd.__version__}")
except ImportError:
    print("[✗] Pandas \t\t - غير مثبت!")
    all_successful = False

try:
    import matplotlib
    print(f"[✓] Matplotlib \t\t version: {matplotlib.__version__}")
except ImportError:
    print("[✗] Matplotlib \t\t - غير مثبتة!")
    all_successful = False

try:
    import seaborn as sns
    print(f"[✓] Seaborn \t\t version: {sns.__version__}")
except ImportError:
    print("[✗] Seaborn \t\t - غير مثبت!")
    all_successful = False

try:
    import sklearn
    print(f"[✓] Scikit-learn \t version: {sklearn.__version__}")
except ImportError:
    print("[✗] Scikit-learn \t - غير مثبتة!")
    all_successful = False


# --- 2. مكتبات الذكاء الاصطناعي المتخصصة ---
print_header("2. مكتبات الذكاء الاصطناعي المتخصصة")
try:
    import skfuzzy
    print(f"[✓] scikit-fuzzy \t version: {skfuzzy.__version__}")
except ImportError:
    print("[✗] scikit-fuzzy \t - غير مثبتة!")
    all_successful = False

try:
    import deap
    print(f"[✓] DEAP \t\t version: {deap.__version__}")
except ImportError:
    print("[✗] DEAP \t\t - غير مثبتة!")
    all_successful = False

try:
    import experta
    print("[✓] experta \t\t - تم الاستيراد بنجاح.")
except ImportError:
    print("[✗] experta \t\t - غير مثبتة!")
    all_successful = False


# --- 3. مكتبات التعلم العميق (قد تستغرق لحظات) ---
# ملاحظة: قد تظهر بعض رسائل المعلومات (INFO) أو التحذيرات (WARNING) عند استيرادها، وهذا طبيعي.
print_header("3. مكتبات التعلم العميق")
try:
    import tensorflow as tf
    print(f"[✓] TensorFlow \t\t version: {tf.__version__}")
except ImportError:
    print("[✗] TensorFlow \t - غير مثبتة!")
    all_successful = False

try:
    import torch
    print(f"[✓] PyTorch \t\t version: {torch.__version__}")
except ImportError:
    print("[✗] PyTorch \t\t - غير مثبت!")
    all_successful = False


# --- 4. مكتبات الويب، الألعاب، والأدوات المساعدة ---
print_header("4. مكتبات الويب والألعاب")
try:
    import flask
    print(f"[✓] Flask \t\t version: {flask.__version__}")
except ImportError:
    print("[✗] Flask \t\t - غير مثبت!")
    all_successful = False

try:
    import pygame
    print(f"[✓] Pygame \t\t version: {pygame.version.ver}")
except ImportError:
    print("[✗] Pygame \t\t - غير مثبت!")
    all_successful = False

try:
    from frozendict import frozendict
    print("[✓] frozendict \t\t - تم الاستيراد بنجاح.")
except ImportError:
    print("[✗] frozendict \t\t - غير مثبت!")
    all_successful = False


# --- الملخص النهائي ---
print("\n" + "="*50)
if all_successful:
    print("\n🎉🎉🎉 رائع! جميع المكتبات مثبتة بشكل صحيح.")
    print("بيئة العمل لديك جاهزة تماماً للانطلاق في الدورة.")
else:
    print("\n⚠️ تنبيه: تم العثور على مشاكل في التثبيت.")
    print("الرجاء مراجعة الأسطر التي تبدأ بـ [✗] أعلاه.")
    print("حاول إعادة تنفيذ أوامر التثبيت والتحديث من دليل المكتبات مرة أخرى.")
print("="*50)
# Out:
# ...
# بدء عملية التحقق من تثبيت مكتبات الدورة...
# ...
#
# --------------- 1. مكتبات علم البيانات الأساسية ---------------
# [✓] NumPy 		 version: 2.1.3
# [✓] Pandas 		 version: 2.3.0
# [✓] Matplotlib 		 version: 3.10.3
# [✓] Seaborn 		 version: 0.13.2
# [✓] Scikit-learn 	 version: 1.7.0
#
# --------------- 2. مكتبات الذكاء الاصطناعي المتخصصة ---------------
# [✓] scikit-fuzzy 	 version: 0.5.0
# [✓] DEAP 		 version: 1.4
# [✓] experta 		 - تم الاستيراد بنجاح.
#
# --------------- 3. مكتبات التعلم العميق ---------------
# [✓] TensorFlow 		 version: 2.19.0
# [✓] PyTorch 		 version: 2.7.1+cpu
#
# --------------- 4. مكتبات الويب والألعاب ---------------
# C:\Users\Osamm\AppData\Local\Temp\ipykernel_10024\3410154511.py:103: DeprecationWarning: The '__version__' attribute is deprecated and will be removed in Flask 3.2. Use feature detection or 'importlib.metadata.version("flask")' instead.
#   print(f"[✓] Flask \t\t version: {flask.__version__}")
# ...
